# %% [markdown]
# # Ice Sheet Model Comparison Tool
#
# This tool, like the ISMIP6 Ice Sheet Model Comparison Tool, provides direct access to ISMIP6 ice sheet model files on the CCR.
#
# This tool, plots a single variable from one or several ISMIP6 ice sheet models for visual inspection and comparison. The output shows plots of the user-selected variable from each model and from a reference dataset (the IMAUICE1 ice sheet model). Note, that not all variables and experiments will have a reference dataset. Users can also choose a range of data per variable to be visualized.

# %%
# import packages 
import os
import sys
import io

import numpy as np
import xarray as xr

import matplotlib
import matplotlib.pyplot as plt

import cartopy
import cartopy.crs as ccrs

import ipywidgets as widgets
from IPython.display import display

import path
from greenland import plot_greenland_basemap
from Antarctica import plot_antarctica_basemap

# %%
from widgets import display_widgets

# Display the widgets
display_widgets()
# Out:
# Dropdown(description='Select Data Path:', options=('Select Path', 'Antarctic Ice Sheet (AIS)', 'Greenland Ice …
# RadioButtons(description='Select Experiment:', options=('Select Experiment',), value='Select Experiment')
# RadioButtons(description='Select Variable:', options=('Select Variable',), value='Select Variable')
# SelectMultiple(description='Select Model Group:', options=('Select Model Group',), value=())
# Button(description='Confirm Model Group Selection', style=ButtonStyle())
# BoundedIntText(value=0, description='Select Date Index:', max=86)
# Button(description='Confirm Date Selection', style=ButtonStyle())
# Button(button_style='warning', description='Clear/Reset', style=ButtonStyle(), tooltip='Click to reset all sel…

# %%
'''
Next Steps:
1. For the Select Model groups, add in a progress bar to see how long it takes for users for the filter to work (under 30 seconds normally). 
2. Next, add in a value range of the data users want to be extracted and visualized
    2A. Prevously state for each variable what the typical data range is there (SelectionRangeSlider widget can be used)
    2B. Have a date section for what time period to extract data? (Ask professor)
3. Have a confirm button
    3A. Have a progress bar to show how long it is taking with a precentage
4. Create Maps of GIS & AIS (DONE)
5. Plot the extracted data on the maps. 
'''

# %%
plot_greenland_basemap()

# %%
plot_antarctica_basemap()
